# %% [markdown]
# # Bounding Box Regression - Four Corner Predict

# %%
from ast import literal_eval
from matplotlib import pyplot as plt
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import cv2
import tensorflow as tf
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
INIT_LR = 1e-4
NUM_EPOCHS = 25
BATCH_SIZE = 32

own_data_path = 'D:/Github/Spliddit/'

# %% [markdown]
# # Preprocess Data
# The data is preprocessed in the following manner:
# - Loading the labels
# - Scaling the labels so that they correspond to the scaled image with 100x100
# - Normalizing the label to be between 0 and 1
# - Loading and scaling the image

# %% [markdown]
# ### 1. Loading the labels

# %%
#labels_own = pd.read_csv('D:/Github/Spliddit/labels.csv', dtype={'count' : int})
#labels_own['label'] = [literal_eval(x) for x in labels_own.label]

#labels_doc = pd.read_csv('D:/Github/Spliddit/SmartDoc/labels_original.csv', dtype={'count' : int})
#labels_doc['label'] = [literal_eval(x) for x in labels_doc.label]

#labels = labels_own.append(labels_doc).reset_index(drop=True)
#labels = labels.sample(frac=1).reset_index(drop=True)

labels = pd.read_csv('D:/Github/Spliddit/labels_complete.csv', dtype={'count' : int})
labels['label'] = [literal_eval(x) for x in labels.label]

# %%
labels.head()
# Out:
#    count                                          label  \
# 0  15498     (630, 256, 1096, 181, 1299, 800, 752, 923)
# 1   2776     (769, 387, 1079, 363, 1210, 756, 857, 809)
# 2   8245     (841, 278, 1198, 255, 1293, 704, 862, 731)
# 3  15468     (651, 209, 1060, 199, 1106, 725, 607, 742)
# 4   4638  (465, 1072, 3687, 977, 3736, 2006, 469, 2044)
#
#                                                 path
# 0  D:/Github/Spliddit/SmartDoc/SmartDocFrames/001...
# 1  D:/Github/Spliddit/SmartDoc/SmartDocFrames/000...
# 2  D:/Github/Spliddit/SmartDoc/SmartDocFrames/000...
# 3  D:/Github/Spliddit/SmartDoc/SmartDocFrames/001...
# 4             D:/Github/Spliddit/dataset/0004638.jpg

# %% [markdown]
# ### 2. Scaling the labels

# %%
def scale_label(height, width, label):
    """Returns the scaled version of the labels so that they
    correspond to the scaled image with a width and height of 100."""
    width_factor = 100/width
    height_factor = 100/height
    label_scaled = []
    for i in range(len(label)):
        if i % 2 == 0:
            label_scaled.append(int(label[i] * width_factor))
        else:
            label_scaled.append(int(label[i] * height_factor))
    return tuple(label_scaled)

# %%
x = []
y = []

for i in tqdm(range(labels.shape[0])):
    label = labels.iloc[i, 1]
    img_path = labels.iloc[i, -1]
    img = cv2.imread(img_path)
    height, width = img.shape[:2]
    img = cv2.resize(img, (100,100))
    img = img.astype('float32') / 255
    x.append(img)
    labels_scaled = scale_label(height, width, label)
    labels_normalized = tuple([x/100 for x in labels_scaled])
    y.append(labels_normalized)

x_processed = np.array(x)
y_processed = np.array(y)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 33593/33593 [58:51<00:00,  9.51it/s]

# %%
x_processed.shape
# Out:
# (33593, 100, 100, 3)

# %%
y_processed.shape
# Out:
# (33593, 8)

# %% [markdown]
# # Splitting the dataset

# %%
x_train, x_test, y_train, y_test = train_test_split(x_processed, y_processed, test_size=0.10, random_state=42)

# writing the data to disk for later use
np.save('D:/Github/Spliddit/final_dataset/x_train.npy', x_train)
np.save('D:/Github/Spliddit/final_dataset/x_test.npy', x_test)
np.save('D:/Github/Spliddit/final_dataset/y_train.npy', y_train)
np.save('D:/Github/Spliddit/final_dataset/y_test.npy', y_test)

# %%
# alternatively: loading the data

x_train = np.load('D:/Github/Spliddit/final_dataset/x_train.npy')
x_test = np.load('D:/Github/Spliddit/final_dataset/x_test.npy')
y_train = np.load('D:/Github/Spliddit/final_dataset/y_train.npy')
y_test = np.load('D:/Github/Spliddit/final_dataset/y_test.npy')

# %% [markdown]
# # Rebuilding the RecursiveCNN-Architecture

# %%
import tensorflow as tf

from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# Building the model

# %%
model = models.Sequential()
model.add(layers.Conv2D(20, (5, 5), activation='relu', input_shape=(100, 100, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(40, (5, 5), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(40, (5, 5), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(60, (5, 5), activation='relu'))
model.add(layers.Conv2D(60, (5, 5), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(500))
model.add(layers.Dense(500))
model.add(layers.Dense(8))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 20)        1520
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 20)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 40)        20040
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 22, 40)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 18, 40)        40040
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 9, 40)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 5, 60)          60060
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 1, 1, 60)          90060
# _________________________________________________________________
# flatten (Flatten)            (None, 60)                0
# _________________________________________________________________
# dense (Dense)                (None, 500)               30500
# _________________________________________________________________
# dense_1 (Dense)              (None, 500)               250500
# _________________________________________________________________
# dense_2 (Dense)              (None, 8)                 4008
# =================================================================
# Total params: 496,728
# Trainable params: 496,728
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = Adam(lr=INIT_LR)
model.compile(loss="mse", optimizer=opt)
#latest = tf.train.latest_checkpoint('D:/Github/Spliddit/models/own_model/')
#model.load_weights(latest)

# %% [markdown]
# Set checkpoints

# %%
# Creating model Checkpoints
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "D:/Github/Spliddit/models/four_corner_model/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)


# Create a callback that saves the model's weights every 5 epochs
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq='epoch')

# %%
history_own = model.fit(
	x_train, y_train,
	validation_data=(x_test, y_test),
	batch_size=BATCH_SIZE,
	epochs=NUM_EPOCHS,
	verbose=1,
    callbacks = [cp_callback])
# Out:
# Epoch 1/25
# 945/945 [==============================] - 346s 364ms/step - loss: 0.0181 - val_loss: 0.0040
#
# Epoch 00001: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0001.ckpt
# Epoch 2/25
# 945/945 [==============================] - 355s 376ms/step - loss: 0.0036 - val_loss: 0.0026
#
# Epoch 00002: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0002.ckpt
# Epoch 3/25
# 945/945 [==============================] - 348s 369ms/step - loss: 0.0026 - val_loss: 0.0023
#
# Epoch 00003: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0003.ckpt
# Epoch 4/25
# 945/945 [==============================] - 348s 369ms/step - loss: 0.0020 - val_loss: 0.0018
#
# Epoch 00004: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0004.ckpt
# Epoch 5/25
# 945/945 [==============================] - 346s 366ms/step - loss: 0.0016 - val_loss: 0.0015
#
# Epoch 00005: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0005.ckpt
# Epoch 6/25
# 945/945 [==============================] - 342s 362ms/step - loss: 0.0014 - val_loss: 0.0014
#
# Epoch 00006: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0006.ckpt
# Epoch 7/25
# 945/945 [==============================] - 341s 361ms/step - loss: 0.0011 - val_loss: 0.0012
#
# Epoch 00007: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0007.ckpt
# Epoch 8/25
# 945/945 [==============================] - 343s 362ms/step - loss: 0.0010 - val_loss: 0.0011
#
# Epoch 00008: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0008.ckpt
# Epoch 9/25
# 945/945 [==============================] - 342s 362ms/step - loss: 8.5884e-04 - val_loss: 0.0011
#
# Epoch 00009: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0009.ckpt
# Epoch 10/25
# 945/945 [==============================] - 348s 368ms/step - loss: 7.2403e-04 - val_loss: 0.0010
#
# Epoch 00010: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0010.ckpt
# Epoch 11/25
# 945/945 [==============================] - 342s 362ms/step - loss: 6.1710e-04 - val_loss: 9.2935e-04
#
# Epoch 00011: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0011.ckpt
# Epoch 12/25
# 945/945 [==============================] - 341s 361ms/step - loss: 5.4232e-04 - val_loss: 8.2886e-04
#
# Epoch 00012: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0012.ckpt
# Epoch 13/25
# 945/945 [==============================] - 341s 361ms/step - loss: 4.7538e-04 - val_loss: 9.5124e-04
#
# Epoch 00013: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0013.ckpt
# Epoch 14/25
# 945/945 [==============================] - 350s 371ms/step - loss: 4.2334e-04 - val_loss: 8.2736e-04
#
# Epoch 00014: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0014.ckpt
# Epoch 15/25
# 945/945 [==============================] - 342s 362ms/step - loss: 3.8331e-04 - val_loss: 7.5567e-04
#
# Epoch 00015: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0015.ckpt
# Epoch 16/25
# 945/945 [==============================] - 342s 362ms/step - loss: 3.3547e-04 - val_loss: 6.9256e-04
#
# Epoch 00016: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0016.ckpt
# Epoch 17/25
# 945/945 [==============================] - 341s 361ms/step - loss: 3.0500e-04 - val_loss: 6.9579e-04
#
# Epoch 00017: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0017.ckpt
# Epoch 18/25
# 945/945 [==============================] - 342s 362ms/step - loss: 2.8922e-04 - val_loss: 6.5547e-04
#
# Epoch 00018: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0018.ckpt
# Epoch 19/25
# 945/945 [==============================] - 340s 360ms/step - loss: 2.5969e-04 - val_loss: 6.8226e-04
#
# Epoch 00019: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0019.ckpt
# Epoch 20/25
# 945/945 [==============================] - 340s 360ms/step - loss: 2.3818e-04 - val_loss: 6.6788e-04
#
# Epoch 00020: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0020.ckpt
# Epoch 21/25
# 945/945 [==============================] - 340s 360ms/step - loss: 2.3526e-04 - val_loss: 6.3186e-04
#
# Epoch 00021: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0021.ckpt
# Epoch 22/25
# 945/945 [==============================] - 342s 362ms/step - loss: 2.0809e-04 - val_loss: 5.8615e-04
#
# Epoch 00022: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0022.ckpt
# Epoch 23/25
# 945/945 [==============================] - 342s 361ms/step - loss: 2.0046e-04 - val_loss: 6.0033e-04
#
# Epoch 00023: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0023.ckpt
# Epoch 24/25
# 945/945 [==============================] - 341s 361ms/step - loss: 1.8441e-04 - val_loss: 5.7849e-04
#
# Epoch 00024: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0024.ckpt
# Epoch 25/25
# 945/945 [==============================] - 341s 361ms/step - loss: 1.8648e-04 - val_loss: 5.6766e-04
#
# Epoch 00025: saving model to D:/Github/Spliddit/models/four_corner_model\cp-0025.ckpt

# %%
model.save('D:/Github/Spliddit/models/four_corner_model/full_model')
# Out:
# INFO:tensorflow:Assets written to: D:/Github/Spliddit/models/four_corner_model/full_model\assets

# %% [markdown]
# # Testing on new receipts

# %%
model = tf.keras.models.load_model('D:/Github/Spliddit/models/own_model/new/model')

# %% [markdown]
# ### 1. Reading new images and making a prediction

# %%
test_images = 0
for file in os.listdir('testset/'):
    test_img = cv2.imread('testset/' + file, 1)
    test_img = cv2.resize(test_img, (100, 100))
    #img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    test_img = test_img.astype('float32') / 255
    if type(test_images) == int:
        test_images = test_img
    else:
        test_images = np.vstack((test_images, test_img))

# %%
test_images = np.expand_dims(test_images, -1)
test_images = test_images.reshape((-1, 100, 100, 3))

# %%
test_images.shape
# Out:
# (7, 100, 100, 3)

# %%
y_pred = model.predict(test_images)

# %%
y_pred.shape
# Out:
# (7, 8)

# %% [markdown]
# ### 2. Denormalizing and upscaling the result
# Denormalization is achieved by multiplying the width by 600 and the height by 800

# %%
y_pred_denormalized = y_pred * 100
y_pred_denormalized = y_pred_denormalized.astype(int)

# %% [markdown]
# Upscaling is achieved by dividing the label by its width and height factors. Since we know the resolution of the test images, we set a constant width and height factor

# %%
def descale_result(y_pred):
    width_factor = 100/2268
    height_factor = 100/4032
    pred_descaled = []
    for row in y_pred:
        row_descaled = []
        for cell_index in range(len(row)):
            if(cell_index % 2 == 0):
                row_descaled.append(int(row[cell_index] / height_factor))
            else:
                row_descaled.append(int(row[cell_index] / width_factor))
        pred_descaled.append(row_descaled)
    return pred_descaled

y_pred_descaled = descale_result(y_pred_denormalized)

# %%
y_pred_descaled
# Out:
# [[887, 340, 2378, 340, 2298, 1769, 806, 1723],
#  [967, 181, 3386, 181, 3064, 1950, 1128, 1973],
#  [1209, 113, 2378, 113, 2661, 1950, 1451, 1950],
#  [1008, 385, 2580, 385, 2701, 1723, 1128, 1746],
#  [766, 181, 2419, 158, 2459, 1837, 806, 1837],
#  [967, 408, 2822, 385, 2822, 1769, 1048, 1769],
#  [725, 249, 3427, 272, 3104, 2109, 887, 2109]]

# %% [markdown]
# ### 3. Draw result on test image
# Reading the test images

# %%
to_display = []

for file in os.listdir('testset/'):
    test_img = cv2.imread('testset/' + file, 1)
    to_display.append(test_img)
    #to_display.append(cv2.resize(test_img, (100,100)))

# %% [markdown]
# Drawing the bounding box

# %%
def display_bounding_box(img, coords):
    temp = get_coord_pairs(coords)
    # alternative scale
    scaled = []
    for i in temp:
        scaled.append((int(i[0] * 2268), int(i[1] * 4032)))
    temp = scaled
    
    print(temp)
    cv2.circle(img, temp[0], 5, (255,0,0), thickness=-1)
    cv2.circle(img, temp[1], 5,(255,0,0), thickness=-1)
    cv2.circle(img, temp[2], 5,(255,0,0), thickness=-1)
    cv2.circle(img, temp[3], 5,(255,0,0), thickness=-1)
    img = cv2.resize(img, (600, 800))
    cv2.imshow("Outline", img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
def get_coord_pairs(coords):
    return [(coords[0], coords[1]), (coords[2], coords[3]), (coords[4], coords[5]), (coords[6], coords[7])]

# %%
display_bounding_box(to_display[6], y_pred[6])
# Out:
# [(427, 460), (1935, 508), (1746, 3773), (502, 3750)]

# %% [markdown]
# # Corner Refiner

# %%
from ast import literal_eval
from matplotlib import pyplot as plt
from tqdm import tqdm
import pandas as pd
import numpy as np
import os
import cv2
import tensorflow as tf
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# %%
INIT_LR = 1e-4
NUM_EPOCHS = 20
BATCH_SIZE = 32

own_data_path = 'D:/Github/Spliddit/'

# %% [markdown]
# # Preprocess Data
# The data is preprocessed in the following manner:
# - Loading the labels
# - Scaling the labels so that they correspond to the scaled image with 100x100
# - Normalizing the label to be between 0 and 1
# - Loading and scaling the image

# %% [markdown]
# ### 1. Loading the labels

# %%
#labels_own = pd.read_csv('D:/Github/Spliddit/labels.csv', dtype={'count' : int})
#labels_own['label'] = [literal_eval(x) for x in labels_own.label]

#labels_doc = pd.read_csv('D:/Github/Spliddit/SmartDoc/labels_original.csv', dtype={'count' : int})
#labels_doc['label'] = [literal_eval(x) for x in labels_doc.label]

#labels = labels_own.append(labels_doc).reset_index(drop=True)
#labels = labels.sample(frac=1).reset_index(drop=True)

labels = pd.read_csv('D:/Github/Spliddit/labels_corner_refiner_zoom.csv', dtype={'count' : int})
labels['label'] = [literal_eval(x) for x in labels.label]

# %%
labels.head()
# Out:
#    count       label                                            path
# 0      0  (630, 256)  D:/Github/Spliddit/dataset_refiner/0000000.jpg
# 1      1  (233, 181)  D:/Github/Spliddit/dataset_refiner/0000001.jpg
# 2      2  (274, 310)  D:/Github/Spliddit/dataset_refiner/0000002.jpg
# 3      3  (752, 334)  D:/Github/Spliddit/dataset_refiner/0000003.jpg
# 4      4  (769, 387)  D:/Github/Spliddit/dataset_refiner/0000004.jpg

# %% [markdown]
# ### 2. Scaling the labels

# %%
def scale_label(height, width, label):
    """Returns the scaled version of the labels so that they
    correspond to the scaled image with a width and height of 100."""
    width_factor = 100/width
    height_factor = 100/height
    label_scaled = []
    for i in range(len(label)):
        if i % 2 == 0:
            label_scaled.append(int(label[i] * width_factor))
        else:
            label_scaled.append(int(label[i] * height_factor))
    return tuple(label_scaled)

# %%
x = []
y = []

for i in tqdm(range(0, int(labels.shape[0] / 2))):
    label = labels.iloc[i, 1]
    img_path = labels.iloc[i, -1]
    img = cv2.imread(img_path)
    height, width = img.shape[:2]
    img = cv2.resize(img, (100,100))
    img = img.astype('float32') / 255
    x.append(img)
    labels_scaled = scale_label(height, width, label)
    labels_normalized = tuple([x/100 for x in labels_scaled])
    y.append(labels_normalized)

#x_processed = np.array(x)
#y_processed = np.array(y)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 134372/134372 [1:38:33<00:00, 22.72it/s]

# %% [markdown]
# # Splitting the data
# ... into train and test set as well as data chunks because of memory issues

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
for i in range(0, 13):
    print(i, ' / 13')
    start_big = int(i*(len(x_train)/13))
    end_big = int(start_big +(len(x_train)/13))
    np.save('D:/Github/Spliddit/final_dataset/corner_refiner/x_train_' + str(i) + '.npy', np.array(x_train[start_big:end_big]))
    np.save('D:/Github/Spliddit/final_dataset/corner_refiner/y_train_' + str(i) + '.npy', np.array(y_train[start_big:end_big]))
    
    start_small = int(i*(len(x_test)/13))
    end_small = int(start_small +(len(x_test)/13))
    np.save('D:/Github/Spliddit/final_dataset/corner_refiner/x_test_' + str(i) + '.npy', np.array(x_test[start_small:end_small]))
    np.save('D:/Github/Spliddit/final_dataset/corner_refiner/y_test_' + str(i) + '.npy', np.array(y_test[start_small:end_small]))
# Out:
# 0  / 13
# 1  / 13
# 2  / 13
# 3  / 13
# 4  / 13
# 5  / 13
# 6  / 13
# 7  / 13
# 8  / 13
# 9  / 13
# 10  / 13
# 11  / 13
# 12  / 13

# %% [markdown]
# # 2nd half

# %%
import gc
del x
del y
del x_train
del x_test
del y_train
del y_test

# %%
gc.collect()
# Out:
# 2165

# %%
x = []
y = []

for i in tqdm(range(int(labels.shape[0]/2), labels.shape[0])):
    label = labels.iloc[i, 1]
    img_path = labels.iloc[i, -1]
    img = cv2.imread(img_path)
    height, width = img.shape[:2]
    img = cv2.resize(img, (100,100))
    img = img.astype('float32') / 255
    x.append(img)
    labels_scaled = scale_label(height, width, label)
    labels_normalized = tuple([x/100 for x in labels_scaled])
    y.append(labels_normalized)

#x_processed = np.array(x)
#y_processed = np.array(y)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 134372/134372 [1:01:13<00:00, 36.58it/s]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.10, random_state=42)

# %%
for i in range(13, 26):
    print(i, ' / 25')
    i_calc = i - 13
    start_big = int(i_calc*(len(x_train)/13))
    end_big = int(start_big +(len(x_train)/13))
    np.save('D:/Github/Spliddit/final_dataset/corner_refiner/x_train_' + str(i) + '.npy', np.array(x_train[start_big:end_big]))
    np.save('D:/Github/Spliddit/final_dataset/corner_refiner/y_train_' + str(i) + '.npy', np.array(y_train[start_big:end_big]))
    
    start_small = int(i_calc*(len(x_test)/13))
    end_small = int(start_small +(len(x_test)/13))
    np.save('D:/Github/Spliddit/final_dataset/corner_refiner/x_test_' + str(i) + '.npy', np.array(x_test[start_small:end_small]))
    np.save('D:/Github/Spliddit/final_dataset/corner_refiner/y_test_' + str(i) + '.npy', np.array(y_test[start_small:end_small]))
# Out:
# 13  / 25
# 14  / 25
# 15  / 25
# 16  / 25
# 17  / 25
# 18  / 25
# 19  / 25
# 20  / 25
# 21  / 25
# 22  / 25
# 23  / 25
# 24  / 25
# 25  / 25

# %% [markdown]
# # Rebuilding the RecursiveCNN-Architecture

# %%
import tensorflow as tf

from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# Building the model

# %%
model = models.Sequential()
model.add(layers.Conv2D(10, (5, 5), activation='relu', input_shape=(100, 100, 3)))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(10, (5, 5), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(20, (5, 5), activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(30, (5, 5), activation='relu'))
model.add(layers.BatchNormalization())
#model.add(layers.Conv2D(40, (5, 5), activation='relu'))

model.add(layers.Flatten())
model.add(layers.Dense(300))
model.add(layers.Dense(2))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 10)        760
# _________________________________________________________________
# batch_normalization (BatchNo (None, 96, 96, 10)        40
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 10)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 44, 44, 10)        2510
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 44, 44, 10)        40
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 22, 22, 10)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 18, 20)        5020
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 20)        80
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 9, 20)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 5, 30)          15030
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 5, 5, 30)          120
# _________________________________________________________________
# flatten (Flatten)            (None, 750)               0
# _________________________________________________________________
# dense (Dense)                (None, 300)               225300
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 602
# =================================================================
# Total params: 249,502
# Trainable params: 249,362
# Non-trainable params: 140
# _________________________________________________________________

# %%
opt = Adam(lr=INIT_LR)
model.compile(loss="mse", optimizer=opt)
latest = tf.train.latest_checkpoint('D:/Github/Spliddit/models/corner_refiner_model/')
model.load_weights(latest)

# %% [markdown]
# Set checkpoints

# %%
# Creating model Checkpoints
# Include the epoch in the file name (uses `str.format`)
checkpoint_path = "D:/Github/Spliddit/models/corner_refiner_model/cp-{epoch:04d}.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)


# Create a callback that saves the model's weights every epoch
cp_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_path, 
    verbose=1, 
    save_weights_only=True,
    save_freq='epoch')

# %%
in_ep = 0

for i in range(0, 26):
    print('\n\n***************************')
    print('*********** ' + str(i) + ' ***********')
    print('***************************\n\n')
    
    # loading the data chunk
    x_train = np.load('D:/Github/Spliddit/final_dataset/corner_refiner/x_train_' + str(i) + '.npy')
    x_test = np.load('D:/Github/Spliddit/final_dataset/corner_refiner/x_test_' + str(i) + '.npy')
    y_train = np.load('D:/Github/Spliddit/final_dataset/corner_refiner/y_train_' + str(i) + '.npy')
    y_test = np.load('D:/Github/Spliddit/final_dataset/corner_refiner/y_test_' + str(i) + '.npy')
    
    history_own = model.fit(
	x_train, y_train,
	validation_data=(x_test, y_test),
	batch_size=BATCH_SIZE,
	epochs= 20 + in_ep,
	verbose=1,
    callbacks = [cp_callback],
    initial_epoch = in_ep)
    
    in_ep += 20
# Out:
# ***************************
# *********** 0 ***********
# ***************************
#
#
# Epoch 1/20
# 291/291 [==============================] - 100s 343ms/step - loss: 0.9585 - val_loss: 0.1101
#
# Epoch 00001: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0001.ckpt
# Epoch 2/20
# 291/291 [==============================] - 99s 339ms/step - loss: 0.1081 - val_loss: 0.0591
#
# Epoch 00002: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0002.ckpt
# Epoch 3/20
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0614 - val_loss: 0.0562
#
# Epoch 00003: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0003.ckpt
# Epoch 4/20
# 291/291 [==============================] - 99s 340ms/step - loss: 0.0501 - val_loss: 0.0597
#
# Epoch 00004: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0004.ckpt
# Epoch 5/20
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0438 - val_loss: 0.0550
#
# Epoch 00005: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0005.ckpt
# Epoch 6/20
# 291/291 [==============================] - 99s 342ms/step - loss: 0.0451 - val_loss: 0.0478
#
# Epoch 00006: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0006.ckpt
# Epoch 7/20
# 291/291 [==============================] - 102s 349ms/step - loss: 0.0414 - val_loss: 0.0396
#
# Epoch 00007: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0007.ckpt
# Epoch 8/20
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0377 - val_loss: 0.0429
#
# Epoch 00008: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0008.ckpt
# Epoch 9/20
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0341 - val_loss: 0.0419
#
# Epoch 00009: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0009.ckpt
# Epoch 10/20
# 291/291 [==============================] - 94s 323ms/step - loss: 0.0352 - val_loss: 0.0580
#
# Epoch 00010: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0010.ckpt
# Epoch 11/20
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0365 - val_loss: 0.0346
#
# Epoch 00011: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0011.ckpt
# Epoch 12/20
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0344 - val_loss: 0.0535
#
# Epoch 00012: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0012.ckpt
# Epoch 13/20
# 291/291 [==============================] - 94s 322ms/step - loss: 0.0349 - val_loss: 0.0463
#
# Epoch 00013: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0013.ckpt
# Epoch 14/20
# 291/291 [==============================] - 94s 322ms/step - loss: 0.0315 - val_loss: 0.0382
#
# Epoch 00014: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0014.ckpt
# Epoch 15/20
# 291/291 [==============================] - 94s 323ms/step - loss: 0.0300 - val_loss: 0.0422
#
# Epoch 00015: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0015.ckpt
# Epoch 16/20
# 291/291 [==============================] - 94s 323ms/step - loss: 0.0316 - val_loss: 0.0355
#
# Epoch 00016: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0016.ckpt
# Epoch 17/20
# 291/291 [==============================] - 94s 322ms/step - loss: 0.0306 - val_loss: 0.0381
#
# Epoch 00017: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0017.ckpt
# Epoch 18/20
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0293 - val_loss: 0.0346
#
# Epoch 00018: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0018.ckpt
# Epoch 19/20
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0284 - val_loss: 0.0380
#
# Epoch 00019: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0019.ckpt
# Epoch 20/20
# 291/291 [==============================] - 94s 322ms/step - loss: 0.0266 - val_loss: 0.0373
#
# Epoch 00020: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0020.ckpt
#
#
# ***************************
# *********** 1 ***********
# ***************************
#
#
# Epoch 21/40
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0401 - val_loss: 0.0390
#
# Epoch 00021: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0021.ckpt
# Epoch 22/40
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0345 - val_loss: 0.0308
#
# Epoch 00022: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0022.ckpt
# Epoch 23/40
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0351 - val_loss: 0.0312
#
# Epoch 00023: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0023.ckpt
# Epoch 24/40
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0317 - val_loss: 0.0360
#
# Epoch 00024: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0024.ckpt
# Epoch 25/40
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0289 - val_loss: 0.0896
#
# Epoch 00025: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0025.ckpt
# Epoch 26/40
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0317 - val_loss: 0.0311
#
# Epoch 00026: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0026.ckpt
# Epoch 27/40
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0272 - val_loss: 0.0324
#
# Epoch 00027: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0027.ckpt
# Epoch 28/40
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0282 - val_loss: 0.0303
#
# Epoch 00028: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0028.ckpt
# Epoch 29/40
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0262 - val_loss: 0.0650
#
# Epoch 00029: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0029.ckpt
# Epoch 30/40
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0250 - val_loss: 0.0323
#
# Epoch 00030: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0030.ckpt
# Epoch 31/40
# 291/291 [==============================] - 99s 342ms/step - loss: 0.0236 - val_loss: 0.0385
#
# Epoch 00031: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0031.ckpt
# Epoch 32/40
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0225 - val_loss: 0.0295
#
# Epoch 00032: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0032.ckpt
# Epoch 33/40
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0221 - val_loss: 0.0391
#
# Epoch 00033: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0033.ckpt
# Epoch 34/40
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0203 - val_loss: 0.0360
#
# Epoch 00034: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0034.ckpt
# Epoch 35/40
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0193 - val_loss: 0.0362
#
# Epoch 00035: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0035.ckpt
# Epoch 36/40
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0214 - val_loss: 0.0369
#
# Epoch 00036: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0036.ckpt
# Epoch 37/40
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0174 - val_loss: 0.0439
#
# Epoch 00037: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0037.ckpt
# Epoch 38/40
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0182 - val_loss: 0.0352
#
# Epoch 00038: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0038.ckpt
# Epoch 39/40
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0166 - val_loss: 0.0319
#
# Epoch 00039: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0039.ckpt
# Epoch 40/40
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0153 - val_loss: 0.0332
#
# Epoch 00040: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0040.ckpt
#
#
# ***************************
# *********** 2 ***********
# ***************************
#
#
# Epoch 41/60
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0357 - val_loss: 0.0303
#
# Epoch 00041: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0041.ckpt
# Epoch 42/60
# 291/291 [==============================] - 92s 315ms/step - loss: 0.0308 - val_loss: 0.0284
#
# Epoch 00042: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0042.ckpt
# Epoch 43/60
# 291/291 [==============================] - 92s 318ms/step - loss: 0.0291 - val_loss: 0.0478
#
# Epoch 00043: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0043.ckpt
# Epoch 44/60
# 291/291 [==============================] - 93s 320ms/step - loss: 0.0275 - val_loss: 0.0348
#
# Epoch 00044: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0044.ckpt
# Epoch 45/60
# 291/291 [==============================] - 93s 321ms/step - loss: 0.0255 - val_loss: 0.0298
#
# Epoch 00045: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0045.ckpt
# Epoch 46/60
# 291/291 [==============================] - 94s 322ms/step - loss: 0.0245 - val_loss: 0.0315
#
# Epoch 00046: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0046.ckpt
# Epoch 47/60
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0232 - val_loss: 0.0281
#
# Epoch 00047: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0047.ckpt
# Epoch 48/60
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0207 - val_loss: 0.0338
#
# Epoch 00048: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0048.ckpt
# Epoch 49/60
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0185 - val_loss: 0.0279
#
# Epoch 00049: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0049.ckpt
# Epoch 50/60
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0187 - val_loss: 0.0310
#
# Epoch 00050: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0050.ckpt
# Epoch 51/60
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0190 - val_loss: 0.0324
#
# Epoch 00051: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0051.ckpt
# Epoch 52/60
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0162 - val_loss: 0.0322
#
# Epoch 00052: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0052.ckpt
# Epoch 53/60
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0161 - val_loss: 0.0309
#
# Epoch 00053: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0053.ckpt
# Epoch 54/60
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0145 - val_loss: 0.0310
#
# Epoch 00054: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0054.ckpt
# Epoch 55/60
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0148 - val_loss: 0.0424
#
# Epoch 00055: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0055.ckpt
# Epoch 56/60
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0143 - val_loss: 0.0349
#
# Epoch 00056: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0056.ckpt
# Epoch 57/60
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0136 - val_loss: 0.0345
#
# Epoch 00057: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0057.ckpt
# Epoch 58/60
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0126 - val_loss: 0.0364
#
# Epoch 00058: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0058.ckpt
# Epoch 59/60
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0119 - val_loss: 0.0334
#
# Epoch 00059: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0059.ckpt
# Epoch 60/60
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0114 - val_loss: 0.0345
#
# Epoch 00060: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0060.ckpt
#
#
# ***************************
# *********** 3 ***********
# ***************************
#
#
# Epoch 61/80
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0354 - val_loss: 0.0246
#
# Epoch 00061: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0061.ckpt
# Epoch 62/80
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0278 - val_loss: 0.0258
#
# Epoch 00062: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0062.ckpt
# Epoch 63/80
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0258 - val_loss: 0.0326
#
# Epoch 00063: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0063.ckpt
# Epoch 64/80
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0253 - val_loss: 0.0242
#
# Epoch 00064: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0064.ckpt
# Epoch 65/80
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0224 - val_loss: 0.0238
#
# Epoch 00065: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0065.ckpt
# Epoch 66/80
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0196 - val_loss: 0.0317
#
# Epoch 00066: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0066.ckpt
# Epoch 67/80
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0191 - val_loss: 0.0265
#
# Epoch 00067: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0067.ckpt
# Epoch 68/80
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0166 - val_loss: 0.0317
#
# Epoch 00068: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0068.ckpt
# Epoch 69/80
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0162 - val_loss: 0.0251
#
# Epoch 00069: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0069.ckpt
# Epoch 70/80
# 291/291 [==============================] - 93s 319ms/step - loss: 0.0150 - val_loss: 0.0257
#
# Epoch 00070: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0070.ckpt
# Epoch 71/80
# 291/291 [==============================] - 93s 320ms/step - loss: 0.0138 - val_loss: 0.0284
#
# Epoch 00071: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0071.ckpt
# Epoch 72/80
# 291/291 [==============================] - 94s 322ms/step - loss: 0.0139 - val_loss: 0.0282
#
# Epoch 00072: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0072.ckpt
# Epoch 73/80
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0131 - val_loss: 0.0281
#
# Epoch 00073: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0073.ckpt
# Epoch 74/80
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0125 - val_loss: 0.0296
#
# Epoch 00074: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0074.ckpt
# Epoch 75/80
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0116 - val_loss: 0.0282
#
# Epoch 00075: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0075.ckpt
# Epoch 76/80
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0115 - val_loss: 0.0344
#
# Epoch 00076: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0076.ckpt
# Epoch 77/80
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0114 - val_loss: 0.0279
#
# Epoch 00077: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0077.ckpt
# Epoch 78/80
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0103 - val_loss: 0.0270
#
# Epoch 00078: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0078.ckpt
# Epoch 79/80
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0099 - val_loss: 0.0264
#
# Epoch 00079: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0079.ckpt
# Epoch 80/80
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0100 - val_loss: 0.0264
#
# Epoch 00080: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0080.ckpt
#
#
# ***************************
# *********** 4 ***********
# ***************************
#
#
# Epoch 81/100
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0327 - val_loss: 0.0265
#
# Epoch 00081: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0081.ckpt
# Epoch 82/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0252 - val_loss: 0.0277
#
# Epoch 00082: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0082.ckpt
# Epoch 83/100
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0226 - val_loss: 0.0247
#
# Epoch 00083: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0083.ckpt
# Epoch 84/100
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0206 - val_loss: 0.0281
#
# Epoch 00084: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0084.ckpt
# Epoch 85/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0198 - val_loss: 0.0221
#
# Epoch 00085: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0085.ckpt
# Epoch 86/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0187 - val_loss: 0.0242
#
# Epoch 00086: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0086.ckpt
# Epoch 87/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0178 - val_loss: 0.0228
#
# Epoch 00087: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0087.ckpt
# Epoch 88/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0157 - val_loss: 0.0274
#
# Epoch 00088: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0088.ckpt
# Epoch 89/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0152 - val_loss: 0.0244
#
# Epoch 00089: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0089.ckpt
# Epoch 90/100
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0139 - val_loss: 0.0254
#
# Epoch 00090: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0090.ckpt
# Epoch 91/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0127 - val_loss: 0.0245
#
# Epoch 00091: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0091.ckpt
# Epoch 92/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0127 - val_loss: 0.0262
#
# Epoch 00092: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0092.ckpt
# Epoch 93/100
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0114 - val_loss: 0.0253
#
# Epoch 00093: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0093.ckpt
# Epoch 94/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0116 - val_loss: 0.0387
#
# Epoch 00094: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0094.ckpt
# Epoch 95/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0111 - val_loss: 0.0275
#
# Epoch 00095: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0095.ckpt
# Epoch 96/100
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0100 - val_loss: 0.0278
#
# Epoch 00096: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0096.ckpt
# Epoch 97/100
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0099 - val_loss: 0.0249
#
# Epoch 00097: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0097.ckpt
# Epoch 98/100
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0095 - val_loss: 0.0255
#
# Epoch 00098: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0098.ckpt
# Epoch 99/100
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0085 - val_loss: 0.0279
#
# Epoch 00099: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0099.ckpt
# Epoch 100/100
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0082 - val_loss: 0.0277
#
# Epoch 00100: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0100.ckpt
#
#
# ***************************
# *********** 5 ***********
# ***************************
#
#
# Epoch 101/120
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0275 - val_loss: 0.0508
#
# Epoch 00101: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0101.ckpt
# Epoch 102/120
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0221 - val_loss: 0.0212
#
# Epoch 00102: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0102.ckpt
# Epoch 103/120
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0195 - val_loss: 0.0215
#
# Epoch 00103: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0103.ckpt
# Epoch 104/120
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0179 - val_loss: 0.0230
#
# Epoch 00104: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0104.ckpt
# Epoch 105/120
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0167 - val_loss: 0.0253
#
# Epoch 00105: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0105.ckpt
# Epoch 106/120
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0151 - val_loss: 0.0216
#
# Epoch 00106: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0106.ckpt
# Epoch 107/120
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0144 - val_loss: 0.0217
#
# Epoch 00107: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0107.ckpt
# Epoch 108/120
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0130 - val_loss: 0.0219
#
# Epoch 00108: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0108.ckpt
# Epoch 109/120
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0123 - val_loss: 0.0255
#
# Epoch 00109: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0109.ckpt
# Epoch 110/120
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0115 - val_loss: 0.0224
#
# Epoch 00110: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0110.ckpt
# Epoch 111/120
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0106 - val_loss: 0.0231
#
# Epoch 00111: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0111.ckpt
# Epoch 112/120
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0099 - val_loss: 0.0251
#
# Epoch 00112: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0112.ckpt
# Epoch 113/120
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0095 - val_loss: 0.0272
#
# Epoch 00113: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0113.ckpt
# Epoch 114/120
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0090 - val_loss: 0.0253
#
# Epoch 00114: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0114.ckpt
# Epoch 115/120
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0089 - val_loss: 0.0233
#
# Epoch 00115: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0115.ckpt
# Epoch 116/120
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0079 - val_loss: 0.0248
#
# Epoch 00116: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0116.ckpt
# Epoch 117/120
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0076 - val_loss: 0.0270
#
# Epoch 00117: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0117.ckpt
# Epoch 118/120
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0072 - val_loss: 0.0251
#
# Epoch 00118: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0118.ckpt
# Epoch 119/120
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0071 - val_loss: 0.0294
#
# Epoch 00119: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0119.ckpt
# Epoch 120/120
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0070 - val_loss: 0.0271
#
# Epoch 00120: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0120.ckpt
#
#
# ***************************
# *********** 6 ***********
# ***************************
#
#
# Epoch 121/140
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0261 - val_loss: 0.0289
#
# Epoch 00121: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0121.ckpt
# Epoch 122/140
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0200 - val_loss: 0.0249
#
# Epoch 00122: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0122.ckpt
# Epoch 123/140
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0184 - val_loss: 0.0212
#
# Epoch 00123: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0123.ckpt
# Epoch 124/140
# 291/291 [==============================] - 95s 328ms/step - loss: 0.0168 - val_loss: 0.0245
#
# Epoch 00124: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0124.ckpt
# Epoch 125/140
# 291/291 [==============================] - 92s 317ms/step - loss: 0.0152 - val_loss: 0.0238
#
# Epoch 00125: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0125.ckpt
# Epoch 126/140
# 291/291 [==============================] - 93s 318ms/step - loss: 0.0138 - val_loss: 0.0236
#
# Epoch 00126: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0126.ckpt
# Epoch 127/140
# 291/291 [==============================] - 93s 319ms/step - loss: 0.0128 - val_loss: 0.0246
#
# Epoch 00127: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0127.ckpt
# Epoch 128/140
# 291/291 [==============================] - 94s 323ms/step - loss: 0.0117 - val_loss: 0.0240
#
# Epoch 00128: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0128.ckpt
# Epoch 129/140
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0110 - val_loss: 0.0247
#
# Epoch 00129: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0129.ckpt
# Epoch 130/140
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0101 - val_loss: 0.0249
#
# Epoch 00130: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0130.ckpt
# Epoch 131/140
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0098 - val_loss: 0.0264
#
# Epoch 00131: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0131.ckpt
# Epoch 132/140
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0092 - val_loss: 0.0257
#
# Epoch 00132: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0132.ckpt
# Epoch 133/140
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0088 - val_loss: 0.0262
#
# Epoch 00133: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0133.ckpt
# Epoch 134/140
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0086 - val_loss: 0.0266
#
# Epoch 00134: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0134.ckpt
# Epoch 135/140
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0076 - val_loss: 0.0254
#
# Epoch 00135: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0135.ckpt
# Epoch 136/140
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0071 - val_loss: 0.0265
#
# Epoch 00136: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0136.ckpt
# Epoch 137/140
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0070 - val_loss: 0.0266
#
# Epoch 00137: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0137.ckpt
# Epoch 138/140
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0067 - val_loss: 0.0261
#
# Epoch 00138: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0138.ckpt
# Epoch 139/140
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0065 - val_loss: 0.0259
#
# Epoch 00139: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0139.ckpt
# Epoch 140/140
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0061 - val_loss: 0.0267
#
# Epoch 00140: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0140.ckpt
#
#
# ***************************
# *********** 7 ***********
# ***************************
#
#
# Epoch 141/160
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0238 - val_loss: 0.0214
#
# Epoch 00141: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0141.ckpt
# Epoch 142/160
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0188 - val_loss: 0.0205
#
# Epoch 00142: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0142.ckpt
# Epoch 143/160
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0166 - val_loss: 0.0213
#
# Epoch 00143: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0143.ckpt
# Epoch 144/160
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0153 - val_loss: 0.0195
#
# Epoch 00144: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0144.ckpt
# Epoch 145/160
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0136 - val_loss: 0.0214
#
# Epoch 00145: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0145.ckpt
# Epoch 146/160
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0125 - val_loss: 0.0206
#
# Epoch 00146: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0146.ckpt
# Epoch 147/160
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0116 - val_loss: 0.0198
#
# Epoch 00147: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0147.ckpt
# Epoch 148/160
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0110 - val_loss: 0.0195
#
# Epoch 00148: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0148.ckpt
# Epoch 149/160
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0099 - val_loss: 0.0202
#
# Epoch 00149: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0149.ckpt
# Epoch 150/160
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0090 - val_loss: 0.0207
#
# Epoch 00150: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0150.ckpt
# Epoch 151/160
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0083 - val_loss: 0.0212
#
# Epoch 00151: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0151.ckpt
# Epoch 152/160
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0081 - val_loss: 0.0202
#
# Epoch 00152: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0152.ckpt
# Epoch 153/160
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0074 - val_loss: 0.0217
#
# Epoch 00153: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0153.ckpt
# Epoch 154/160
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0070 - val_loss: 0.0210
#
# Epoch 00154: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0154.ckpt
# Epoch 155/160
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0065 - val_loss: 0.0208
#
# Epoch 00155: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0155.ckpt
# Epoch 156/160
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0064 - val_loss: 0.0219
#
# Epoch 00156: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0156.ckpt
# Epoch 157/160
# 291/291 [==============================] - 92s 315ms/step - loss: 0.0060 - val_loss: 0.0208
#
# Epoch 00157: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0157.ckpt
# Epoch 158/160
# 291/291 [==============================] - 92s 315ms/step - loss: 0.0057 - val_loss: 0.0215
#
# Epoch 00158: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0158.ckpt
# Epoch 159/160
# 291/291 [==============================] - 92s 316ms/step - loss: 0.0056 - val_loss: 0.0213
#
# Epoch 00159: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0159.ckpt
# Epoch 160/160
# 291/291 [==============================] - 92s 315ms/step - loss: 0.0053 - val_loss: 0.0225
#
# Epoch 00160: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0160.ckpt
#
#
# ***************************
# *********** 8 ***********
# ***************************
#
#
# Epoch 161/180
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0229 - val_loss: 0.0189
#
# Epoch 00161: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0161.ckpt
# Epoch 162/180
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0181 - val_loss: 0.0201
#
# Epoch 00162: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0162.ckpt
# Epoch 163/180
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0165 - val_loss: 0.0196
#
# Epoch 00163: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0163.ckpt
# Epoch 164/180
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0145 - val_loss: 0.0189
#
# Epoch 00164: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0164.ckpt
# Epoch 165/180
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0133 - val_loss: 0.0182
#
# Epoch 00165: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0165.ckpt
# Epoch 166/180
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0120 - val_loss: 0.0180
#
# Epoch 00166: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0166.ckpt
# Epoch 167/180
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0109 - val_loss: 0.0190
#
# Epoch 00167: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0167.ckpt
# Epoch 168/180
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0101 - val_loss: 0.0188
#
# Epoch 00168: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0168.ckpt
# Epoch 169/180
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0094 - val_loss: 0.0195
#
# Epoch 00169: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0169.ckpt
# Epoch 170/180
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0087 - val_loss: 0.0194
#
# Epoch 00170: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0170.ckpt
# Epoch 171/180
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0081 - val_loss: 0.0204
#
# Epoch 00171: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0171.ckpt
# Epoch 172/180
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0074 - val_loss: 0.0199
#
# Epoch 00172: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0172.ckpt
# Epoch 173/180
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0071 - val_loss: 0.0216
#
# Epoch 00173: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0173.ckpt
# Epoch 174/180
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0067 - val_loss: 0.0208
#
# Epoch 00174: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0174.ckpt
# Epoch 175/180
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0064 - val_loss: 0.0206
#
# Epoch 00175: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0175.ckpt
# Epoch 176/180
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0060 - val_loss: 0.0206
#
# Epoch 00176: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0176.ckpt
# Epoch 177/180
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0058 - val_loss: 0.0216
#
# Epoch 00177: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0177.ckpt
# Epoch 178/180
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0055 - val_loss: 0.0212
#
# Epoch 00178: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0178.ckpt
# Epoch 179/180
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0052 - val_loss: 0.0203
#
# Epoch 00179: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0179.ckpt
# Epoch 180/180
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0050 - val_loss: 0.0213
#
# Epoch 00180: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0180.ckpt
#
#
# ***************************
# *********** 9 ***********
# ***************************
#
#
# Epoch 181/200
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0212 - val_loss: 0.0211
#
# Epoch 00181: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0181.ckpt
# Epoch 182/200
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0169 - val_loss: 0.0198
#
# Epoch 00182: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0182.ckpt
# Epoch 183/200
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0150 - val_loss: 0.0191
#
# Epoch 00183: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0183.ckpt
# Epoch 184/200
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0135 - val_loss: 0.0188
#
# Epoch 00184: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0184.ckpt
# Epoch 185/200
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0122 - val_loss: 0.0184
#
# Epoch 00185: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0185.ckpt
# Epoch 186/200
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0113 - val_loss: 0.0202
#
# Epoch 00186: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0186.ckpt
# Epoch 187/200
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0100 - val_loss: 0.0197
#
# Epoch 00187: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0187.ckpt
# Epoch 188/200
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0093 - val_loss: 0.0198
#
# Epoch 00188: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0188.ckpt
# Epoch 189/200
# 291/291 [==============================] - 92s 315ms/step - loss: 0.0086 - val_loss: 0.0224
#
# Epoch 00189: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0189.ckpt
# Epoch 190/200
# 291/291 [==============================] - 92s 316ms/step - loss: 0.0080 - val_loss: 0.0206
#
# Epoch 00190: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0190.ckpt
# Epoch 191/200
# 291/291 [==============================] - 92s 316ms/step - loss: 0.0072 - val_loss: 0.0206
#
# Epoch 00191: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0191.ckpt
# Epoch 192/200
# 291/291 [==============================] - 92s 316ms/step - loss: 0.0068 - val_loss: 0.0216
#
# Epoch 00192: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0192.ckpt
# Epoch 193/200
# 291/291 [==============================] - 92s 318ms/step - loss: 0.0067 - val_loss: 0.0218
#
# Epoch 00193: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0193.ckpt
# Epoch 194/200
# 291/291 [==============================] - 92s 317ms/step - loss: 0.0061 - val_loss: 0.0218
#
# Epoch 00194: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0194.ckpt
# Epoch 195/200
# 291/291 [==============================] - 93s 319ms/step - loss: 0.0058 - val_loss: 0.0227
#
# Epoch 00195: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0195.ckpt
# Epoch 196/200
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0054 - val_loss: 0.0228
#
# Epoch 00196: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0196.ckpt
# Epoch 197/200
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0051 - val_loss: 0.0231
#
# Epoch 00197: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0197.ckpt
# Epoch 198/200
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0048 - val_loss: 0.0229
#
# Epoch 00198: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0198.ckpt
# Epoch 199/200
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0048 - val_loss: 0.0228
#
# Epoch 00199: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0199.ckpt
# Epoch 200/200
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0046 - val_loss: 0.0234
#
# Epoch 00200: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0200.ckpt
#
#
# ***************************
# *********** 10 ***********
# ***************************
#
#
# Epoch 201/220
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0198 - val_loss: 0.0173
#
# Epoch 00201: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0201.ckpt
# Epoch 202/220
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0154 - val_loss: 0.0187
#
# Epoch 00202: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0202.ckpt
# Epoch 203/220
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0138 - val_loss: 0.0178
#
# Epoch 00203: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0203.ckpt
# Epoch 204/220
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0123 - val_loss: 0.0171
#
# Epoch 00204: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0204.ckpt
# Epoch 205/220
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0109 - val_loss: 0.0171
#
# Epoch 00205: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0205.ckpt
# Epoch 206/220
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0100 - val_loss: 0.0173
#
# Epoch 00206: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0206.ckpt
# Epoch 207/220
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0091 - val_loss: 0.0192
#
# Epoch 00207: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0207.ckpt
# Epoch 208/220
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0082 - val_loss: 0.0181
#
# Epoch 00208: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0208.ckpt
# Epoch 209/220
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0075 - val_loss: 0.0193
#
# Epoch 00209: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0209.ckpt
# Epoch 210/220
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0069 - val_loss: 0.0191
#
# Epoch 00210: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0210.ckpt
# Epoch 211/220
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0065 - val_loss: 0.0203
#
# Epoch 00211: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0211.ckpt
# Epoch 212/220
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0061 - val_loss: 0.0197
#
# Epoch 00212: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0212.ckpt
# Epoch 213/220
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0056 - val_loss: 0.0194
#
# Epoch 00213: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0213.ckpt
# Epoch 214/220
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0052 - val_loss: 0.0192
#
# Epoch 00214: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0214.ckpt
# Epoch 215/220
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0051 - val_loss: 0.0207
#
# Epoch 00215: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0215.ckpt
# Epoch 216/220
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0049 - val_loss: 0.0208
#
# Epoch 00216: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0216.ckpt
# Epoch 217/220
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0046 - val_loss: 0.0193
#
# Epoch 00217: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0217.ckpt
# Epoch 218/220
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0043 - val_loss: 0.0198
#
# Epoch 00218: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0218.ckpt
# Epoch 219/220
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0043 - val_loss: 0.0204
#
# Epoch 00219: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0219.ckpt
# Epoch 220/220
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0039 - val_loss: 0.0200
#
# Epoch 00220: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0220.ckpt
#
#
# ***************************
# *********** 11 ***********
# ***************************
#
#
# Epoch 221/240
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0195 - val_loss: 0.0177
#
# Epoch 00221: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0221.ckpt
# Epoch 222/240
# 291/291 [==============================] - 95s 328ms/step - loss: 0.0154 - val_loss: 0.0175
#
# Epoch 00222: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0222.ckpt
# Epoch 223/240
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0135 - val_loss: 0.0175
#
# Epoch 00223: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0223.ckpt
# Epoch 224/240
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0122 - val_loss: 0.0177
#
# Epoch 00224: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0224.ckpt
# Epoch 225/240
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0109 - val_loss: 0.0183
#
# Epoch 00225: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0225.ckpt
# Epoch 226/240
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0099 - val_loss: 0.0179
#
# Epoch 00226: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0226.ckpt
# Epoch 227/240
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0089 - val_loss: 0.0190
#
# Epoch 00227: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0227.ckpt
# Epoch 228/240
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0082 - val_loss: 0.0189
#
# Epoch 00228: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0228.ckpt
# Epoch 229/240
# 291/291 [==============================] - 100s 344ms/step - loss: 0.0076 - val_loss: 0.0187
#
# Epoch 00229: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0229.ckpt
# Epoch 230/240
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0069 - val_loss: 0.0188
#
# Epoch 00230: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0230.ckpt
# Epoch 231/240
# 291/291 [==============================] - 104s 357ms/step - loss: 0.0065 - val_loss: 0.0191
#
# Epoch 00231: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0231.ckpt
# Epoch 232/240
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0060 - val_loss: 0.0193
#
# Epoch 00232: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0232.ckpt
# Epoch 233/240
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0056 - val_loss: 0.0194
#
# Epoch 00233: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0233.ckpt
# Epoch 234/240
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0053 - val_loss: 0.0192
#
# Epoch 00234: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0234.ckpt
# Epoch 235/240
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0049 - val_loss: 0.0202
#
# Epoch 00235: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0235.ckpt
# Epoch 236/240
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0049 - val_loss: 0.0201
#
# Epoch 00236: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0236.ckpt
# Epoch 237/240
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0045 - val_loss: 0.0212
#
# Epoch 00237: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0237.ckpt
# Epoch 238/240
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0044 - val_loss: 0.0199
#
# Epoch 00238: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0238.ckpt
# Epoch 239/240
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0043 - val_loss: 0.0201
#
# Epoch 00239: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0239.ckpt
# Epoch 240/240
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0040 - val_loss: 0.0208
#
# Epoch 00240: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0240.ckpt
#
#
# ***************************
# *********** 12 ***********
# ***************************
#
#
# Epoch 241/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0183 - val_loss: 0.0180
#
# Epoch 00241: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0241.ckpt
# Epoch 242/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0144 - val_loss: 0.0171
#
# Epoch 00242: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0242.ckpt
# Epoch 243/260
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0130 - val_loss: 0.0162
#
# Epoch 00243: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0243.ckpt
# Epoch 244/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0116 - val_loss: 0.0165
#
# Epoch 00244: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0244.ckpt
# Epoch 245/260
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0106 - val_loss: 0.0160
#
# Epoch 00245: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0245.ckpt
# Epoch 246/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0095 - val_loss: 0.0173
#
# Epoch 00246: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0246.ckpt
# Epoch 247/260
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0085 - val_loss: 0.0171
#
# Epoch 00247: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0247.ckpt
# Epoch 248/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0079 - val_loss: 0.0166
#
# Epoch 00248: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0248.ckpt
# Epoch 249/260
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0072 - val_loss: 0.0173
#
# Epoch 00249: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0249.ckpt
# Epoch 250/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0067 - val_loss: 0.0169
#
# Epoch 00250: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0250.ckpt
# Epoch 251/260
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0062 - val_loss: 0.0180
#
# Epoch 00251: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0251.ckpt
# Epoch 252/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0057 - val_loss: 0.0177
#
# Epoch 00252: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0252.ckpt
# Epoch 253/260
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0054 - val_loss: 0.0175
#
# Epoch 00253: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0253.ckpt
# Epoch 254/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0050 - val_loss: 0.0190
#
# Epoch 00254: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0254.ckpt
# Epoch 255/260
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0049 - val_loss: 0.0184
#
# Epoch 00255: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0255.ckpt
# Epoch 256/260
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0046 - val_loss: 0.0198
#
# Epoch 00256: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0256.ckpt
# Epoch 257/260
# 291/291 [==============================] - 94s 325ms/step - loss: 0.0043 - val_loss: 0.0194
#
# Epoch 00257: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0257.ckpt
# Epoch 258/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0040 - val_loss: 0.0193
#
# Epoch 00258: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0258.ckpt
# Epoch 259/260
# 291/291 [==============================] - 94s 324ms/step - loss: 0.0039 - val_loss: 0.0200
#
# Epoch 00259: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0259.ckpt
# Epoch 260/260
# 291/291 [==============================] - 95s 325ms/step - loss: 0.0038 - val_loss: 0.0196
#
# Epoch 00260: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0260.ckpt
#
#
# ***************************
# *********** 13 ***********
# ***************************
#
#
# Epoch 261/280
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-94963bf68345> in <module>
#      19         verbose=1,
#      20     callbacks = [cp_callback],
# ---> 21     initial_epoch = in_ep)
#      22
#      23     in_ep += 20
#
# c:\users\sebastian\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1108
#    1109         if logs is None:
# -> 1110           raise ValueError('Expect x to be a non-empty array or dataset.')
#    1111         epoch_logs = copy.copy(logs)
#    1112
#
# ValueError: Expect x to be a non-empty array or dataset.

# %%
in_ep = 260

for i in range(13, 26):
    print('\n\n***************************')
    print('*********** ' + str(i) + ' ***********')
    print('***************************\n\n')
    
    # loading the data chunk
    x_train = np.load('D:/Github/Spliddit/final_dataset/corner_refiner/x_train_' + str(i) + '.npy')
    x_test = np.load('D:/Github/Spliddit/final_dataset/corner_refiner/x_test_' + str(i) + '.npy')
    y_train = np.load('D:/Github/Spliddit/final_dataset/corner_refiner/y_train_' + str(i) + '.npy')
    y_test = np.load('D:/Github/Spliddit/final_dataset/corner_refiner/y_test_' + str(i) + '.npy')
    
    history_own = model.fit(
	x_train, y_train,
	validation_data=(x_test, y_test),
	batch_size=BATCH_SIZE,
	epochs= 20 + in_ep,
	verbose=1,
    callbacks = [cp_callback],
    initial_epoch = in_ep)
    
    in_ep += 20
# Out:
# ***************************
# *********** 13 ***********
# ***************************
#
#
# Epoch 261/280
# 291/291 [==============================] - 101s 343ms/step - loss: 0.0244 - val_loss: 0.0232
#
# Epoch 00261: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0261.ckpt
# Epoch 262/280
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0174 - val_loss: 0.0216
#
# Epoch 00262: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0262.ckpt
# Epoch 263/280
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0167 - val_loss: 0.0218
#
# Epoch 00263: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0263.ckpt
# Epoch 264/280
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0146 - val_loss: 0.0231
#
# Epoch 00264: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0264.ckpt
# Epoch 265/280
# 291/291 [==============================] - 101s 348ms/step - loss: 0.0142 - val_loss: 0.0234
#
# Epoch 00265: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0265.ckpt
# Epoch 266/280
# 291/291 [==============================] - 101s 346ms/step - loss: 0.0130 - val_loss: 0.0237
#
# Epoch 00266: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0266.ckpt
# Epoch 267/280
# 291/291 [==============================] - 99s 340ms/step - loss: 0.0117 - val_loss: 0.0236
#
# Epoch 00267: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0267.ckpt
# Epoch 268/280
# 291/291 [==============================] - 99s 340ms/step - loss: 0.0103 - val_loss: 0.0250
#
# Epoch 00268: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0268.ckpt
# Epoch 269/280
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0099 - val_loss: 0.0247
#
# Epoch 00269: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0269.ckpt
# Epoch 270/280
# 291/291 [==============================] - 97s 332ms/step - loss: 0.0088 - val_loss: 0.0264
#
# Epoch 00270: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0270.ckpt
# Epoch 271/280
# 291/291 [==============================] - 98s 335ms/step - loss: 0.0082 - val_loss: 0.0253
#
# Epoch 00271: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0271.ckpt
# Epoch 272/280
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0078 - val_loss: 0.0259
#
# Epoch 00272: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0272.ckpt
# Epoch 273/280
# 291/291 [==============================] - 100s 344ms/step - loss: 0.0074 - val_loss: 0.0265
#
# Epoch 00273: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0273.ckpt
# Epoch 274/280
# 291/291 [==============================] - 100s 344ms/step - loss: 0.0071 - val_loss: 0.0285
#
# Epoch 00274: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0274.ckpt
# Epoch 275/280
# 291/291 [==============================] - 100s 342ms/step - loss: 0.0067 - val_loss: 0.0268
#
# Epoch 00275: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0275.ckpt
# Epoch 276/280
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0063 - val_loss: 0.0280
#
# Epoch 00276: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0276.ckpt
# Epoch 277/280
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0060 - val_loss: 0.0283
#
# Epoch 00277: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0277.ckpt
# Epoch 278/280
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0056 - val_loss: 0.0281
#
# Epoch 00278: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0278.ckpt
# Epoch 279/280
# 291/291 [==============================] - 100s 342ms/step - loss: 0.0055 - val_loss: 0.0284
#
# Epoch 00279: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0279.ckpt
# Epoch 280/280
# 291/291 [==============================] - 100s 342ms/step - loss: 0.0053 - val_loss: 0.0292
#
# Epoch 00280: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0280.ckpt
#
#
# ***************************
# *********** 14 ***********
# ***************************
#
#
# Epoch 281/300
# 291/291 [==============================] - 99s 340ms/step - loss: 0.0205 - val_loss: 0.0198
#
# Epoch 00281: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0281.ckpt
# Epoch 282/300
# 291/291 [==============================] - 96s 330ms/step - loss: 0.0170 - val_loss: 0.0200
#
# Epoch 00282: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0282.ckpt
# Epoch 283/300
# 291/291 [==============================] - 96s 331ms/step - loss: 0.0156 - val_loss: 0.0208
#
# Epoch 00283: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0283.ckpt
# Epoch 284/300
# 291/291 [==============================] - 96s 330ms/step - loss: 0.0143 - val_loss: 0.0213
#
# Epoch 00284: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0284.ckpt
# Epoch 285/300
# 291/291 [==============================] - 96s 331ms/step - loss: 0.0130 - val_loss: 0.0218
#
# Epoch 00285: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0285.ckpt
# Epoch 286/300
# 291/291 [==============================] - 96s 331ms/step - loss: 0.0117 - val_loss: 0.0225
#
# Epoch 00286: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0286.ckpt
# Epoch 287/300
# 291/291 [==============================] - 96s 330ms/step - loss: 0.0105 - val_loss: 0.0226
#
# Epoch 00287: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0287.ckpt
# Epoch 288/300
# 291/291 [==============================] - 96s 331ms/step - loss: 0.0097 - val_loss: 0.0237
#
# Epoch 00288: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0288.ckpt
# Epoch 289/300
# 291/291 [==============================] - 96s 331ms/step - loss: 0.0089 - val_loss: 0.0243
#
# Epoch 00289: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0289.ckpt
# Epoch 290/300
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0082 - val_loss: 0.0252
#
# Epoch 00290: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0290.ckpt
# Epoch 291/300
# 291/291 [==============================] - 96s 331ms/step - loss: 0.0075 - val_loss: 0.0264
#
# Epoch 00291: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0291.ckpt
# Epoch 292/300
# 291/291 [==============================] - 99s 340ms/step - loss: 0.0071 - val_loss: 0.0255
#
# Epoch 00292: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0292.ckpt
# Epoch 293/300
# 291/291 [==============================] - 100s 344ms/step - loss: 0.0067 - val_loss: 0.0262
#
# Epoch 00293: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0293.ckpt
# Epoch 294/300
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0063 - val_loss: 0.0258
#
# Epoch 00294: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0294.ckpt
# Epoch 295/300
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0059 - val_loss: 0.0256
#
# Epoch 00295: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0295.ckpt
# Epoch 296/300
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0057 - val_loss: 0.0268
#
# Epoch 00296: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0296.ckpt
# Epoch 297/300
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0054 - val_loss: 0.0263
#
# Epoch 00297: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0297.ckpt
# Epoch 298/300
# 291/291 [==============================] - 96s 331ms/step - loss: 0.0052 - val_loss: 0.0256
#
# Epoch 00298: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0298.ckpt
# Epoch 299/300
# 291/291 [==============================] - 96s 328ms/step - loss: 0.0050 - val_loss: 0.0268
#
# Epoch 00299: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0299.ckpt
# Epoch 300/300
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0047 - val_loss: 0.0265
#
# Epoch 00300: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0300.ckpt
#
#
# ***************************
# *********** 15 ***********
# ***************************
#
#
# Epoch 301/320
# 291/291 [==============================] - 96s 328ms/step - loss: 0.0206 - val_loss: 0.0210
#
# Epoch 00301: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0301.ckpt
# Epoch 302/320
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0169 - val_loss: 0.0211
#
# Epoch 00302: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0302.ckpt
# Epoch 303/320
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0155 - val_loss: 0.0202
#
# Epoch 00303: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0303.ckpt
# Epoch 304/320
# 291/291 [==============================] - 95s 328ms/step - loss: 0.0140 - val_loss: 0.0205
#
# Epoch 00304: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0304.ckpt
# Epoch 305/320
# 291/291 [==============================] - 95s 328ms/step - loss: 0.0129 - val_loss: 0.0221
#
# Epoch 00305: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0305.ckpt
# Epoch 306/320
# 291/291 [==============================] - 95s 326ms/step - loss: 0.0118 - val_loss: 0.0228
#
# Epoch 00306: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0306.ckpt
# Epoch 307/320
# 291/291 [==============================] - 95s 328ms/step - loss: 0.0105 - val_loss: 0.0236
#
# Epoch 00307: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0307.ckpt
# Epoch 308/320
# 291/291 [==============================] - 95s 328ms/step - loss: 0.0097 - val_loss: 0.0227
#
# Epoch 00308: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0308.ckpt
# Epoch 309/320
# 291/291 [==============================] - 96s 328ms/step - loss: 0.0089 - val_loss: 0.0247
#
# Epoch 00309: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0309.ckpt
# Epoch 310/320
# 291/291 [==============================] - 96s 329ms/step - loss: 0.0083 - val_loss: 0.0268
#
# Epoch 00310: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0310.ckpt
# Epoch 311/320
# 291/291 [==============================] - 96s 328ms/step - loss: 0.0075 - val_loss: 0.0255
#
# Epoch 00311: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0311.ckpt
# Epoch 312/320
# 291/291 [==============================] - 96s 328ms/step - loss: 0.0072 - val_loss: 0.0256
#
# Epoch 00312: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0312.ckpt
# Epoch 313/320
# 291/291 [==============================] - 96s 329ms/step - loss: 0.0066 - val_loss: 0.0260
#
# Epoch 00313: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0313.ckpt
# Epoch 314/320
# 291/291 [==============================] - 95s 328ms/step - loss: 0.0063 - val_loss: 0.0252
#
# Epoch 00314: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0314.ckpt
# Epoch 315/320
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0060 - val_loss: 0.0262
#
# Epoch 00315: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0315.ckpt
# Epoch 316/320
# 291/291 [==============================] - 96s 328ms/step - loss: 0.0055 - val_loss: 0.0274
#
# Epoch 00316: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0316.ckpt
# Epoch 317/320
# 291/291 [==============================] - 96s 328ms/step - loss: 0.0053 - val_loss: 0.0278
#
# Epoch 00317: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0317.ckpt
# Epoch 318/320
# 291/291 [==============================] - 96s 328ms/step - loss: 0.0052 - val_loss: 0.0273
#
# Epoch 00318: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0318.ckpt
# Epoch 319/320
# 291/291 [==============================] - 95s 328ms/step - loss: 0.0049 - val_loss: 0.0258
#
# Epoch 00319: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0319.ckpt
# Epoch 320/320
# 291/291 [==============================] - 95s 328ms/step - loss: 0.0047 - val_loss: 0.0269
#
# Epoch 00320: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0320.ckpt
#
#
# ***************************
# *********** 16 ***********
# ***************************
#
#
# Epoch 321/340
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0206 - val_loss: 0.0187
#
# Epoch 00321: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0321.ckpt
# Epoch 322/340
# 291/291 [==============================] - 102s 349ms/step - loss: 0.0173 - val_loss: 0.0190
#
# Epoch 00322: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0322.ckpt
# Epoch 323/340
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0157 - val_loss: 0.0184
#
# Epoch 00323: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0323.ckpt
# Epoch 324/340
# 291/291 [==============================] - 99s 342ms/step - loss: 0.0144 - val_loss: 0.0185
#
# Epoch 00324: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0324.ckpt
# Epoch 325/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0132 - val_loss: 0.0185
#
# Epoch 00325: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0325.ckpt
# Epoch 326/340
# 291/291 [==============================] - 101s 348ms/step - loss: 0.0118 - val_loss: 0.0205
#
# Epoch 00326: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0326.ckpt
# Epoch 327/340
# 291/291 [==============================] - 100s 345ms/step - loss: 0.0107 - val_loss: 0.0212
#
# Epoch 00327: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0327.ckpt
# Epoch 328/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0098 - val_loss: 0.0211
#
# Epoch 00328: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0328.ckpt
# Epoch 329/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0090 - val_loss: 0.0216
#
# Epoch 00329: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0329.ckpt
# Epoch 330/340
# 291/291 [==============================] - 101s 346ms/step - loss: 0.0083 - val_loss: 0.0217
#
# Epoch 00330: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0330.ckpt
# Epoch 331/340
# 291/291 [==============================] - 100s 344ms/step - loss: 0.0075 - val_loss: 0.0217
#
# Epoch 00331: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0331.ckpt
# Epoch 332/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0071 - val_loss: 0.0221
#
# Epoch 00332: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0332.ckpt
# Epoch 333/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0066 - val_loss: 0.0233
#
# Epoch 00333: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0333.ckpt
# Epoch 334/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0063 - val_loss: 0.0230
#
# Epoch 00334: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0334.ckpt
# Epoch 335/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0059 - val_loss: 0.0239
#
# Epoch 00335: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0335.ckpt
# Epoch 336/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0056 - val_loss: 0.0229
#
# Epoch 00336: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0336.ckpt
# Epoch 337/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0053 - val_loss: 0.0244
#
# Epoch 00337: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0337.ckpt
# Epoch 338/340
# 291/291 [==============================] - 100s 343ms/step - loss: 0.0050 - val_loss: 0.0228
#
# Epoch 00338: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0338.ckpt
# Epoch 339/340
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0049 - val_loss: 0.0228
#
# Epoch 00339: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0339.ckpt
# Epoch 340/340
# 291/291 [==============================] - 97s 332ms/step - loss: 0.0047 - val_loss: 0.0241
#
# Epoch 00340: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0340.ckpt
#
#
# ***************************
# *********** 17 ***********
# ***************************
#
#
# Epoch 341/360
# 291/291 [==============================] - 97s 332ms/step - loss: 0.0202 - val_loss: 0.0191
#
# Epoch 00341: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0341.ckpt
# Epoch 342/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0170 - val_loss: 0.0201
#
# Epoch 00342: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0342.ckpt
# Epoch 343/360
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0155 - val_loss: 0.0191
#
# Epoch 00343: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0343.ckpt
# Epoch 344/360
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0143 - val_loss: 0.0189
#
# Epoch 00344: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0344.ckpt
# Epoch 345/360
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0130 - val_loss: 0.0206
#
# Epoch 00345: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0345.ckpt
# Epoch 346/360
# 291/291 [==============================] - 98s 335ms/step - loss: 0.0120 - val_loss: 0.0206
#
# Epoch 00346: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0346.ckpt
# Epoch 347/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0111 - val_loss: 0.0209
#
# Epoch 00347: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0347.ckpt
# Epoch 348/360
# 291/291 [==============================] - 97s 332ms/step - loss: 0.0102 - val_loss: 0.0216
#
# Epoch 00348: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0348.ckpt
# Epoch 349/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0091 - val_loss: 0.0221
#
# Epoch 00349: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0349.ckpt
# Epoch 350/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0085 - val_loss: 0.0231
#
# Epoch 00350: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0350.ckpt
# Epoch 351/360
# 291/291 [==============================] - 97s 332ms/step - loss: 0.0077 - val_loss: 0.0238
#
# Epoch 00351: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0351.ckpt
# Epoch 352/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0072 - val_loss: 0.0244
#
# Epoch 00352: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0352.ckpt
# Epoch 353/360
# 291/291 [==============================] - 97s 332ms/step - loss: 0.0069 - val_loss: 0.0241
#
# Epoch 00353: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0353.ckpt
# Epoch 354/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0062 - val_loss: 0.0254
#
# Epoch 00354: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0354.ckpt
# Epoch 355/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0059 - val_loss: 0.0260
#
# Epoch 00355: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0355.ckpt
# Epoch 356/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0056 - val_loss: 0.0263
#
# Epoch 00356: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0356.ckpt
# Epoch 357/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0053 - val_loss: 0.0263
#
# Epoch 00357: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0357.ckpt
# Epoch 358/360
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0052 - val_loss: 0.0270
#
# Epoch 00358: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0358.ckpt
# Epoch 359/360
# 291/291 [==============================] - 97s 332ms/step - loss: 0.0049 - val_loss: 0.0265
#
# Epoch 00359: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0359.ckpt
# Epoch 360/360
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0046 - val_loss: 0.0263
#
# Epoch 00360: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0360.ckpt
#
#
# ***************************
# *********** 18 ***********
# ***************************
#
#
# Epoch 361/380
# 291/291 [==============================] - 96s 331ms/step - loss: 0.0192 - val_loss: 0.0191
#
# Epoch 00361: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0361.ckpt
# Epoch 362/380
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0159 - val_loss: 0.0188
#
# Epoch 00362: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0362.ckpt
# Epoch 363/380
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0144 - val_loss: 0.0194
#
# Epoch 00363: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0363.ckpt
# Epoch 364/380
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0134 - val_loss: 0.0195
#
# Epoch 00364: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0364.ckpt
# Epoch 365/380
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0123 - val_loss: 0.0206
#
# Epoch 00365: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0365.ckpt
# Epoch 366/380
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0111 - val_loss: 0.0201
#
# Epoch 00366: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0366.ckpt
# Epoch 367/380
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0101 - val_loss: 0.0211
#
# Epoch 00367: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0367.ckpt
# Epoch 368/380
# 291/291 [==============================] - 97s 335ms/step - loss: 0.0092 - val_loss: 0.0219
#
# Epoch 00368: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0368.ckpt
# Epoch 369/380
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0085 - val_loss: 0.0230
#
# Epoch 00369: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0369.ckpt
# Epoch 370/380
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0077 - val_loss: 0.0233
#
# Epoch 00370: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0370.ckpt
# Epoch 371/380
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0072 - val_loss: 0.0232
#
# Epoch 00371: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0371.ckpt
# Epoch 372/380
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0066 - val_loss: 0.0237
#
# Epoch 00372: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0372.ckpt
# Epoch 373/380
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0063 - val_loss: 0.0234
#
# Epoch 00373: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0373.ckpt
# Epoch 374/380
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0060 - val_loss: 0.0261
#
# Epoch 00374: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0374.ckpt
# Epoch 375/380
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0057 - val_loss: 0.0247
#
# Epoch 00375: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0375.ckpt
# Epoch 376/380
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0054 - val_loss: 0.0248
#
# Epoch 00376: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0376.ckpt
# Epoch 377/380
# 291/291 [==============================] - 103s 352ms/step - loss: 0.0050 - val_loss: 0.0245
#
# Epoch 00377: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0377.ckpt
# Epoch 378/380
# 291/291 [==============================] - 105s 360ms/step - loss: 0.0049 - val_loss: 0.0273
#
# Epoch 00378: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0378.ckpt
# Epoch 379/380
# 291/291 [==============================] - 103s 353ms/step - loss: 0.0046 - val_loss: 0.0264
#
# Epoch 00379: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0379.ckpt
# Epoch 380/380
# 291/291 [==============================] - 102s 352ms/step - loss: 0.0044 - val_loss: 0.0259
#
# Epoch 00380: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0380.ckpt
#
#
# ***************************
# *********** 19 ***********
# ***************************
#
#
# Epoch 381/400
# 291/291 [==============================] - 101s 347ms/step - loss: 0.0195 - val_loss: 0.0199
#
# Epoch 00381: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0381.ckpt
# Epoch 382/400
# 291/291 [==============================] - 102s 351ms/step - loss: 0.0165 - val_loss: 0.0201
#
# Epoch 00382: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0382.ckpt
# Epoch 383/400
# 291/291 [==============================] - 103s 354ms/step - loss: 0.0150 - val_loss: 0.0195
#
# Epoch 00383: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0383.ckpt
# Epoch 384/400
# 291/291 [==============================] - 102s 349ms/step - loss: 0.0138 - val_loss: 0.0200
#
# Epoch 00384: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0384.ckpt
# Epoch 385/400
# 291/291 [==============================] - 102s 350ms/step - loss: 0.0127 - val_loss: 0.0203
#
# Epoch 00385: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0385.ckpt
# Epoch 386/400
# 291/291 [==============================] - 102s 350ms/step - loss: 0.0115 - val_loss: 0.0215
#
# Epoch 00386: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0386.ckpt
# Epoch 387/400
# 291/291 [==============================] - 103s 355ms/step - loss: 0.0105 - val_loss: 0.0228
#
# Epoch 00387: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0387.ckpt
# Epoch 388/400
# 291/291 [==============================] - 102s 350ms/step - loss: 0.0096 - val_loss: 0.0228
#
# Epoch 00388: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0388.ckpt
# Epoch 389/400
# 291/291 [==============================] - 101s 348ms/step - loss: 0.0088 - val_loss: 0.0238
#
# Epoch 00389: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0389.ckpt
# Epoch 390/400
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0080 - val_loss: 0.0241
#
# Epoch 00390: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0390.ckpt
# Epoch 391/400
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0073 - val_loss: 0.0246
#
# Epoch 00391: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0391.ckpt
# Epoch 392/400
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0069 - val_loss: 0.0253
#
# Epoch 00392: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0392.ckpt
# Epoch 393/400
# 291/291 [==============================] - 104s 356ms/step - loss: 0.0066 - val_loss: 0.0249
#
# Epoch 00393: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0393.ckpt
# Epoch 394/400
# 291/291 [==============================] - 103s 356ms/step - loss: 0.0062 - val_loss: 0.0249
#
# Epoch 00394: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0394.ckpt
# Epoch 395/400
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0059 - val_loss: 0.0260
#
# Epoch 00395: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0395.ckpt
# Epoch 396/400
# 291/291 [==============================] - 97s 335ms/step - loss: 0.0055 - val_loss: 0.0277
#
# Epoch 00396: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0396.ckpt
# Epoch 397/400
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0053 - val_loss: 0.0257
#
# Epoch 00397: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0397.ckpt
# Epoch 398/400
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0049 - val_loss: 0.0257
#
# Epoch 00398: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0398.ckpt
# Epoch 399/400
# 291/291 [==============================] - 100s 344ms/step - loss: 0.0049 - val_loss: 0.0257
#
# Epoch 00399: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0399.ckpt
# Epoch 400/400
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0046 - val_loss: 0.0262
#
# Epoch 00400: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0400.ckpt
#
#
# ***************************
# *********** 20 ***********
# ***************************
#
#
# Epoch 401/420
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0195 - val_loss: 0.0178
#
# Epoch 00401: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0401.ckpt
# Epoch 402/420
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0161 - val_loss: 0.0170
#
# Epoch 00402: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0402.ckpt
# Epoch 403/420
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0146 - val_loss: 0.0172
#
# Epoch 00403: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0403.ckpt
# Epoch 404/420
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0135 - val_loss: 0.0170
#
# Epoch 00404: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0404.ckpt
# Epoch 405/420
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0123 - val_loss: 0.0176
#
# Epoch 00405: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0405.ckpt
# Epoch 406/420
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0112 - val_loss: 0.0183
#
# Epoch 00406: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0406.ckpt
# Epoch 407/420
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0103 - val_loss: 0.0190
#
# Epoch 00407: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0407.ckpt
# Epoch 408/420
# 291/291 [==============================] - 98s 339ms/step - loss: 0.0093 - val_loss: 0.0186
#
# Epoch 00408: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0408.ckpt
# Epoch 409/420
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0085 - val_loss: 0.0195
#
# Epoch 00409: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0409.ckpt
# Epoch 410/420
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0079 - val_loss: 0.0189
#
# Epoch 00410: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0410.ckpt
# Epoch 411/420
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0071 - val_loss: 0.0203
#
# Epoch 00411: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0411.ckpt
# Epoch 412/420
# 291/291 [==============================] - 98s 339ms/step - loss: 0.0066 - val_loss: 0.0199
#
# Epoch 00412: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0412.ckpt
# Epoch 413/420
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0060 - val_loss: 0.0200
#
# Epoch 00413: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0413.ckpt
# Epoch 414/420
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0058 - val_loss: 0.0209
#
# Epoch 00414: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0414.ckpt
# Epoch 415/420
# 291/291 [==============================] - 99s 340ms/step - loss: 0.0055 - val_loss: 0.0204
#
# Epoch 00415: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0415.ckpt
# Epoch 416/420
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0052 - val_loss: 0.0206
#
# Epoch 00416: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0416.ckpt
# Epoch 417/420
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0049 - val_loss: 0.0203
#
# Epoch 00417: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0417.ckpt
# Epoch 418/420
# 291/291 [==============================] - 99s 340ms/step - loss: 0.0047 - val_loss: 0.0205
#
# Epoch 00418: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0418.ckpt
# Epoch 419/420
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0044 - val_loss: 0.0208
#
# Epoch 00419: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0419.ckpt
# Epoch 420/420
# 291/291 [==============================] - 99s 340ms/step - loss: 0.0043 - val_loss: 0.0205
#
# Epoch 00420: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0420.ckpt
#
#
# ***************************
# *********** 21 ***********
# ***************************
#
#
# Epoch 421/440
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0197 - val_loss: 0.0177
#
# Epoch 00421: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0421.ckpt
# Epoch 422/440
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0165 - val_loss: 0.0167
#
# Epoch 00422: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0422.ckpt
# Epoch 423/440
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0152 - val_loss: 0.0170
#
# Epoch 00423: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0423.ckpt
# Epoch 424/440
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0139 - val_loss: 0.0167
#
# Epoch 00424: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0424.ckpt
# Epoch 425/440
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0127 - val_loss: 0.0176
#
# Epoch 00425: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0425.ckpt
# Epoch 426/440
# 291/291 [==============================] - 99s 340ms/step - loss: 0.0116 - val_loss: 0.0178
#
# Epoch 00426: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0426.ckpt
# Epoch 427/440
# 291/291 [==============================] - 99s 341ms/step - loss: 0.0106 - val_loss: 0.0184
#
# Epoch 00427: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0427.ckpt
# Epoch 428/440
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0097 - val_loss: 0.0188
#
# Epoch 00428: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0428.ckpt
# Epoch 429/440
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0089 - val_loss: 0.0195
#
# Epoch 00429: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0429.ckpt
# Epoch 430/440
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0081 - val_loss: 0.0195
#
# Epoch 00430: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0430.ckpt
# Epoch 431/440
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0075 - val_loss: 0.0203
#
# Epoch 00431: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0431.ckpt
# Epoch 432/440
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0070 - val_loss: 0.0202
#
# Epoch 00432: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0432.ckpt
# Epoch 433/440
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0067 - val_loss: 0.0209
#
# Epoch 00433: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0433.ckpt
# Epoch 434/440
# 291/291 [==============================] - 102s 350ms/step - loss: 0.0062 - val_loss: 0.0203
#
# Epoch 00434: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0434.ckpt
# Epoch 435/440
# 291/291 [==============================] - 103s 353ms/step - loss: 0.0058 - val_loss: 0.0212
#
# Epoch 00435: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0435.ckpt
# Epoch 436/440
# 291/291 [==============================] - 102s 350ms/step - loss: 0.0055 - val_loss: 0.0214
#
# Epoch 00436: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0436.ckpt
# Epoch 437/440
# 291/291 [==============================] - 102s 350ms/step - loss: 0.0052 - val_loss: 0.0214
#
# Epoch 00437: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0437.ckpt
# Epoch 438/440
# 291/291 [==============================] - 101s 348ms/step - loss: 0.0049 - val_loss: 0.0220
#
# Epoch 00438: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0438.ckpt
# Epoch 439/440
# 291/291 [==============================] - 101s 348ms/step - loss: 0.0048 - val_loss: 0.0212
#
# Epoch 00439: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0439.ckpt
# Epoch 440/440
# 291/291 [==============================] - 101s 348ms/step - loss: 0.0045 - val_loss: 0.0223
#
# Epoch 00440: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0440.ckpt
#
#
# ***************************
# *********** 22 ***********
# ***************************
#
#
# Epoch 441/460
# 291/291 [==============================] - 101s 346ms/step - loss: 0.0194 - val_loss: 0.0177
#
# Epoch 00441: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0441.ckpt
# Epoch 442/460
# 291/291 [==============================] - 102s 350ms/step - loss: 0.0165 - val_loss: 0.0170
#
# Epoch 00442: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0442.ckpt
# Epoch 443/460
# 291/291 [==============================] - 101s 348ms/step - loss: 0.0152 - val_loss: 0.0171
#
# Epoch 00443: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0443.ckpt
# Epoch 444/460
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0141 - val_loss: 0.0177
#
# Epoch 00444: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0444.ckpt
# Epoch 445/460
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0130 - val_loss: 0.0179
#
# Epoch 00445: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0445.ckpt
# Epoch 446/460
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0120 - val_loss: 0.0184
#
# Epoch 00446: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0446.ckpt
# Epoch 447/460
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0108 - val_loss: 0.0185
#
# Epoch 00447: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0447.ckpt
# Epoch 448/460
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0100 - val_loss: 0.0189
#
# Epoch 00448: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0448.ckpt
# Epoch 449/460
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0092 - val_loss: 0.0201
#
# Epoch 00449: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0449.ckpt
# Epoch 450/460
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0085 - val_loss: 0.0198
#
# Epoch 00450: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0450.ckpt
# Epoch 451/460
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0078 - val_loss: 0.0214
#
# Epoch 00451: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0451.ckpt
# Epoch 452/460
# 291/291 [==============================] - 97s 334ms/step - loss: 0.0073 - val_loss: 0.0203
#
# Epoch 00452: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0452.ckpt
# Epoch 453/460
# 291/291 [==============================] - 97s 335ms/step - loss: 0.0069 - val_loss: 0.0211
#
# Epoch 00453: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0453.ckpt
# Epoch 454/460
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0065 - val_loss: 0.0210
#
# Epoch 00454: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0454.ckpt
# Epoch 455/460
# 291/291 [==============================] - 98s 335ms/step - loss: 0.0061 - val_loss: 0.0210
#
# Epoch 00455: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0455.ckpt
# Epoch 456/460
# 291/291 [==============================] - 98s 335ms/step - loss: 0.0057 - val_loss: 0.0217
#
# Epoch 00456: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0456.ckpt
# Epoch 457/460
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0054 - val_loss: 0.0211
#
# Epoch 00457: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0457.ckpt
# Epoch 458/460
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0053 - val_loss: 0.0215
#
# Epoch 00458: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0458.ckpt
# Epoch 459/460
# 291/291 [==============================] - 98s 335ms/step - loss: 0.0051 - val_loss: 0.0212
#
# Epoch 00459: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0459.ckpt
# Epoch 460/460
# 291/291 [==============================] - 98s 335ms/step - loss: 0.0047 - val_loss: 0.0218
#
# Epoch 00460: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0460.ckpt
#
#
# ***************************
# *********** 23 ***********
# ***************************
#
#
# Epoch 461/480
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0189 - val_loss: 0.0172
#
# Epoch 00461: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0461.ckpt
# Epoch 462/480
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0158 - val_loss: 0.0164
#
# Epoch 00462: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0462.ckpt
# Epoch 463/480
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0146 - val_loss: 0.0172
#
# Epoch 00463: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0463.ckpt
# Epoch 464/480
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0134 - val_loss: 0.0171
#
# Epoch 00464: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0464.ckpt
# Epoch 465/480
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0124 - val_loss: 0.0172
#
# Epoch 00465: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0465.ckpt
# Epoch 466/480
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0115 - val_loss: 0.0175
#
# Epoch 00466: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0466.ckpt
# Epoch 467/480
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0103 - val_loss: 0.0186
#
# Epoch 00467: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0467.ckpt
# Epoch 468/480
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0094 - val_loss: 0.0188
#
# Epoch 00468: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0468.ckpt
# Epoch 469/480
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0087 - val_loss: 0.0193
#
# Epoch 00469: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0469.ckpt
# Epoch 470/480
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0080 - val_loss: 0.0197
#
# Epoch 00470: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0470.ckpt
# Epoch 471/480
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0073 - val_loss: 0.0197
#
# Epoch 00471: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0471.ckpt
# Epoch 472/480
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0068 - val_loss: 0.0204
#
# Epoch 00472: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0472.ckpt
# Epoch 473/480
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0063 - val_loss: 0.0207
#
# Epoch 00473: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0473.ckpt
# Epoch 474/480
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0059 - val_loss: 0.0200
#
# Epoch 00474: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0474.ckpt
# Epoch 475/480
# 291/291 [==============================] - 99s 342ms/step - loss: 0.0055 - val_loss: 0.0207
#
# Epoch 00475: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0475.ckpt
# Epoch 476/480
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0051 - val_loss: 0.0208
#
# Epoch 00476: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0476.ckpt
# Epoch 477/480
# 291/291 [==============================] - 98s 336ms/step - loss: 0.0050 - val_loss: 0.0210
#
# Epoch 00477: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0477.ckpt
# Epoch 478/480
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0047 - val_loss: 0.0209
#
# Epoch 00478: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0478.ckpt
# Epoch 479/480
# 291/291 [==============================] - 99s 339ms/step - loss: 0.0045 - val_loss: 0.0213
#
# Epoch 00479: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0479.ckpt
# Epoch 480/480
# 291/291 [==============================] - 98s 337ms/step - loss: 0.0044 - val_loss: 0.0219
#
# Epoch 00480: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0480.ckpt
#
#
# ***************************
# *********** 24 ***********
# ***************************
#
#
# Epoch 481/500
# 291/291 [==============================] - 107s 369ms/step - loss: 0.0190 - val_loss: 0.0189
#
# Epoch 00481: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0481.ckpt
# Epoch 482/500
# 291/291 [==============================] - 102s 352ms/step - loss: 0.0159 - val_loss: 0.0180
#
# Epoch 00482: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0482.ckpt
# Epoch 483/500
# 291/291 [==============================] - 97s 333ms/step - loss: 0.0144 - val_loss: 0.0177
#
# Epoch 00483: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0483.ckpt
# Epoch 484/500
# 291/291 [==============================] - 96s 331ms/step - loss: 0.0132 - val_loss: 0.0182
#
# Epoch 00484: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0484.ckpt
# Epoch 485/500
# 291/291 [==============================] - 97s 335ms/step - loss: 0.0121 - val_loss: 0.0190
#
# Epoch 00485: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0485.ckpt
# Epoch 486/500
# 291/291 [==============================] - 95s 327ms/step - loss: 0.0109 - val_loss: 0.0204
#
# Epoch 00486: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0486.ckpt
# Epoch 487/500
# 291/291 [==============================] - 98s 338ms/step - loss: 0.0098 - val_loss: 0.0207
#
# Epoch 00487: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0487.ckpt
# Epoch 488/500
# 291/291 [==============================] - 119s 408ms/step - loss: 0.0091 - val_loss: 0.0207
#
# Epoch 00488: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0488.ckpt
# Epoch 489/500
# 291/291 [==============================] - 102s 348ms/step - loss: 0.0083 - val_loss: 0.0216
#
# Epoch 00489: saving model to D:/Github/Spliddit/models/corner_refiner_model\cp-0489.ckpt
# Epoch 490/500
#  56/291 [====>.........................] - ETA: 1:26 - loss: 0.0073
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-15f352b9a759> in <module>
#      19         verbose=1,
#      20     callbacks = [cp_callback],
# ---> 21     initial_epoch = in_ep)
#      22
#      23     in_ep += 20
#
# c:\users\sebastian\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# c:\users\sebastian\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# c:\users\sebastian\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# c:\users\sebastian\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# c:\users\sebastian\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# c:\users\sebastian\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# c:\users\sebastian\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %%
model.save('D:/Github/Spliddit/models/corner_refiner_model/full_model')
# Out:
# INFO:tensorflow:Assets written to: D:/Github/Spliddit/models/corner_refiner_model/full_model\assets

# %%
import tensorflow as tf

# %%
model = tf.keras.models.load_model('D:/Github/Spliddit/models/corner_refiner_model/full_model')
